# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushanr/python3-docs/blob/main/Section_33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web Scraping Project
# ##Introduction
# In this project you'll be building a quotes guessing game. When run, your program will scrape a website for a collection of quotes. Pick one at random and display it. The player will have four chances to guess who said the quote. After every wrong guess they'll get a hint about the author's identity.
#
# ##Requirements
#
# * Create a file called `scraping_project.py` which, when run, grabs data on every quote from the website http://quotes.toscrape.com
#
# * You can use `bs4` and `requests` to get the data. For each quote you should grab the text of the quote, the name of the person who said the quote, and the href of the link to the person's bio. Store all of this information in a list.
#
# * Next, display the quote to the user and ask who said it. The player will have four guesses remaining.
#
# * After each incorrect guess, the number of guesses remaining will decrement. If the player gets to zero guesses without identifying the author, the player loses and the game ends. If the player correctly identifies the author, the player wins!
#
# * After every incorrect guess, the player receives a hint about the author.
#   1. For the first hint, make another request to the author's bio page (this is why
# we originally scrape this data), and tell the player the author's birth date and location.
#
#   2. The next two hints are up to you! Some ideas: the first letter of the author's first name, the first letter of the author's last name, the number of letters in one of the names, etc.
#
# * When the game is over, ask the player if they want to play again. If yes, restart the game with a new quote. If no, the program is complete.
#
# Good luck!

# %%
# my solution

import requests
from bs4 import BeautifulSoup
import csv
from time import sleep
from random import choice
import pickle
from os.path import exists

# !pip install pyfiglet

#----------------------------------------DATA SCRAPING MODULES------------------------------------------------------

data_list = []

def scraper(url):

  response = requests.get(url)
  data = response.text
  soup = BeautifulSoup(data,'html.parser')
  quotes = soup.select('.quote')
  global data_list

  for quote in quotes:
    quote_text = quote.find(class_='text').text
    quote_author = quote.find(class_='author').text
    data_list.append(
        {
            'quote':quote_text,
            'author':quote_author
        }
    )
  return data_list


def crawler():

  if exists('data_list.pickle'): # checks whether file exists in directory
    print()
    print('Data file found. Loading data...','\n')

    with open('data_list.pickle','rb') as file: # 'rb' means read binary
      data_list = pickle.load(file)
    #return data_list

  else:
    print()
    print('No file found. Collecting site data. Please wait...','\n')
    s_url = 'http://quotes.toscrape.com'
    url = s_url

    while True:
      data_list = scraper(url)
      response = requests.get(url)
      data = response.text
      soup = BeautifulSoup(data,'html.parser')

      try:
        next = soup.find(class_='next').contents[1]['href']
        url = s_url + next
      except AttributeError:
        break
      sleep(2)
    print('Data gathering completed sucessfully!','\n')

    with open('data_list.pickle','wb') as file: # saved in .pickle format - 'wb' means write in binary
      pickle.dump(data_list,file)
  
  return data_list


def hint(author):

  author = author.replace(' ','-')
  url = f'https://quotes.toscrape.com/author/{author}/'
  response = requests.get(url)
  data = response.text
  soup = BeautifulSoup(data,'html.parser')
  author_bday = soup.find(class_='author-born-date').text
  author_loc = soup.find(class_='author-born-location').get_text()
  author_des = soup.find(class_='author-description').get_text()
  mask_names = author.split('-')
  mask_names.extend([author.replace('-',' ')])

  for name in mask_names:
    info = author_des.replace(name,'$$$$')
    author_des = info
    info = author_des.replace('$$$$ $$$$','$$$$')
    author_des = info

  try:

    while True:
      author_des = author_des.split('. ')[choice(range(1,10))]

      if author_des.strip() not in ('\n','  ',''):
        break

  except IndexError:
    author_des = author_des.split('. ')[0]

  words = [[char if ind == 0 else '_' for ind,char in enumerate(name)] for name in author.split('-')]
  author_initials = '  '.join([' '.join(word) for word in words])
  return (f'Born on {author_bday} {author_loc}',author_des,author_initials)


#--------------------------------------------------GAME ENGINE-------------------------------------------------------------

url = 'https://raw.githubusercontent.com/kaushanr/python3-docs/main/docs/heading_art.py'
r = requests.get(url)
with open('/content/heading_art.py', 'w') as f:
    f.write(r.text)

from heading_art import heading

data_list = crawler()

print(heading('* TRIVIA TIME *'))
print('Hi there!...let\'s play "guess who said it..."','\n')

def play_game():

  attempts = 4
  _quote_data = choice(data_list)
  quote = _quote_data['quote']
  _author = _quote_data['author']

  hint_result = hint(_author)

  print('Here\'s the quote.','\n')
  print(quote,'\n')

  for i in range(attempts):
    print(f'Guesses remaining : {attempts}')
    attempts -= 1
    user_input = input('Take a guess : ').title()
    if user_input == _author:
      print('You guessed correctly! Congratulations!')
      break
    elif attempts > 0:
      print('Nope, try again!')
      print(f'Here\'s a hint : {hint_result[i]}')
    else:
      print(f'Sorry, you\'ve run out of guesses. The answer was {_author}')
  
  play_again = input('Do you want to play again (Y/N)? : ').lower()
  while not play_again in ('y','n'):
    print('Please enter a valid input!')
    play_again = input('Do you want to play again (Y/N)? : ').lower()

  if play_again == 'n':
    return print('Okay, goodbye.')
  else:
    print()
    print('New Game','\n')
    return play_game() # recalling the same function upon exiting with return to loop through again

play_game()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyfiglet in /usr/local/lib/python3.7/dist-packages (0.8.post1)
#
# Data file found. Loading data...
#
#         _____ ____  _____     _____    _      _____ ___ __  __ _____
# __/\__ |_   _|  _ \|_ _\ \   / /_ _|  / \    |_   _|_ _|  \/  | ____| __/\__
# \    /   | | | |_) || | \ \ / / | |  / _ \     | |  | || |\/| |  _|   \    /
# /_  _\   | | |  _ < | |  \ V /  | | / ___ \    | |  | || |  | | |___  /_  _\
#   \/     |_| |_| \_\___|  \_/  |___/_/   \_\   |_| |___|_|  |_|_____|   \/
#
#
# Hi there!...let's play "guess who said it..."
#
# Here's the quote.
#
# “I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”
#
# Guesses remaining : 4
# Take a guess : gdss
# Nope, try again!
# Here's a hint : Born on November 27, 1942 in Seattle, Washington, The United States
# Guesses remaining : 3
# Take a guess :
# Nope, try again!
# Here's a hint : King, Muddy Waters, Albert King, and Elmore James, rhythm and blues and soul guitarists Curtis Mayfield, Steve Cropper, as well as by some modern jazz.Carlos Santana has suggested that $$$$'s music may have been influenced by his Native American heritage
# Guesses remaining : 2
# Take a guess : dfgfdg
# Nope, try again!
# Here's a hint : J _ _ _  H _ _ _ _ _ _
# Guesses remaining : 1
# Take a guess : dfgdfg
# Sorry, you've run out of guesses. The answer was Jimi Hendrix
# Do you want to play again (Y/N)? : y
#
# New Game
#
# Here's the quote.
#
# “Not all of us can do great things. But we can do small things with great love.”
#
# Guesses remaining : 4
# Take a guess : fxgxfg
# Nope, try again!
# Here's a hint : Born on August 26, 1910 in Skopje, Macedonia, the Former Yugoslav Republic of
# Guesses remaining : 3
# Take a guess :
# Nope, try again!
# Here's a hint :
#         Blessed $$$$ of Calcutta, or $$$$, born Agnes Gonxha Bojaxhiu was an Albanian Roman Catholic nun who founded the Missionaries of Charity in Kolkata (Calcutta), India in 1950
# Guesses remaining : 2
# Take a guess :
# Nope, try again!
# Here's a hint : M _ _ _ _ _  T _ _ _ _ _
# Guesses remaining : 1
# Take a guess : Mother Teresa
# You guessed correctly! Congratulations!
# Do you want to play again (Y/N)? : n
# Okay, goodbye.

# %%
# Web Crawlers with Scrapy

#!pip install scrapy

# %%
# write a python file to directory - run this once only to avoid appending code to file

# %%writefile book_scraper.py 

import scrapy

class BookSpider(scrapy.Spider):

  name = 'bookspider'  
  start_urls = ['http://books.toscrape.com/']

  def parse(self,response):
    for article in response.css('article.product_pod'): # looks at article tags with class = product-pod - css syntax
      yield {
          'price': article.css('.price_color::text').extract_first(),
          'title': article.css('h3 > a::attr(title)').extract_first() # CSS selector syntax used here...
      }
      next = response.css('.next > a::attr(href)').extract_first()
      if next:
        yield response.follow(next,self.parse) # recursion by calling the function internally again
# Out:
# Overwriting book_scraper.py

# %%
# !scrapy runspider -O books.csv book_scraper.py # command line syntax, -O overwrites, -o appends to file
# Out:
# 2022-09-10 16:25:17 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2022-09-10 16:25:17 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.7.13 (default, Apr 24 2022, 01:04:09) - [GCC 7.5.0], pyOpenSSL 22.0.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# 2022-09-10 16:25:17 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2022-09-10 16:25:17 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-09-10 16:25:17 [scrapy.extensions.telnet] INFO: Telnet Password: 15b45df633108f18
# 2022-09-10 16:25:17 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-09-10 16:25:17 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-09-10 16:25:17 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-09-10 16:25:17 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-09-10 16:25:17 [scrapy.core.engine] INFO: Spider opened
# 2022-09-10 16:25:17 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-09-10 16:25:17 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-09-10 16:25:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/> (referer: None)
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£51.77', 'title': 'A Light in the Attic'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£53.74', 'title': 'Tipping the Velvet'}
# 2022-09-10 16:25:17 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET http://books.toscrape.com/catalogue/page-2.html> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£50.10', 'title': 'Soumission'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£47.82', 'title': 'Sharp Objects'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£54.23', 'title': 'Sapiens: A Brief History of Humankind'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£22.65', 'title': 'The Requiem Red'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£33.34', 'title': 'The Dirty Little Secrets of Getting Your Dream Job'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£17.93', 'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£22.60', 'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£52.15', 'title': 'The Black Maria'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£13.99', 'title': 'Starving Hearts (Triangular Trade Trilogy, #1)'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£20.66', 'title': "Shakespeare's Sonnets"}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£17.46', 'title': 'Set Me Free'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£52.29', 'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)"}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£35.02', 'title': 'Rip it Up and Start Again'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£57.25', 'title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£23.88', 'title': 'Olio'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£37.59', 'title': 'Mesaerion: The Best Science Fiction Stories 1800-1849'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£51.33', 'title': 'Libertarianism for Beginners'}
# 2022-09-10 16:25:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-2.html> (referer: http://books.toscrape.com/)
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'price': '£45.17', 'title': "It's Only the Himalayas"}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£12.84', 'title': 'In Her Wake'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£37.32', 'title': 'How Music Works'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£30.52', 'title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£25.27', 'title': 'Chase Me (Paris Nights #2)'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£34.53', 'title': 'Black Dust'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£54.64', 'title': 'Birdsong: A Story in Pictures'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£22.50', 'title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana"}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£53.13', 'title': 'Aladdin and His Wonderful Lamp'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£40.30', 'title': 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£44.18', 'title': 'Wall and Piece'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£17.66', 'title': 'The Four Agreements: A Practical Guide to Personal Freedom'}
# 2022-09-10 16:25:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-3.html> (referer: http://books.toscrape.com/catalogue/page-2.html)
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£31.05', 'title': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£23.82', 'title': 'The Elephant Tree'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£36.89', 'title': 'The Bear and the Piano'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£15.94', 'title': "Sophie's World"}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£33.29', 'title': 'Penny Maybe'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£18.02', 'title': 'Maude (1883-1993):She Grew Up with the country'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£19.63', 'title': 'In a Dark, Dark Wood'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£52.22', 'title': 'Behind Closed Doors'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'price': '£33.63', 'title': "You can't bury them all: Poems"}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£57.31', 'title': 'Slow States of Collapse: Poems'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£26.41', 'title': 'Reasons to Stay Alive'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£47.61', 'title': 'Private Paris (Private #10)'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£23.11', 'title': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£45.07', 'title': 'Without Borders (Wanderlove #1)'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£31.77', 'title': 'When We Collided'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£50.27', 'title': 'We Love You, Charlie Freeman'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£14.27', 'title': 'Untitled Collection: Sabbath Poems 2014'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£44.18', 'title': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£18.78', 'title': 'Unicorn Tracks'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£25.52', 'title': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£16.28', 'title': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£31.12', 'title': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£19.49', 'title': 'This One Summer'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£17.27', 'title': 'Thirst'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£19.09', 'title': 'The Torch Is Passed: A Harding Family Story'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£56.13', 'title': 'The Secret of Dreadwillow Carse'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£56.41', 'title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£56.50', 'title': 'The Past Never Ends'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'price': '£45.22', 'title': 'The Natural History of Us (The Fine Art of Pretending #2)'}
# 2022-09-10 16:25:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-4.html> (referer: http://books.toscrape.com/catalogue/page-3.html)
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£38.16', 'title': 'The Nameless City (The Nameless City #1)'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£54.11', 'title': 'The Murder That Never Was (Forensic Instincts #5)'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£42.96', 'title': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg"}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£23.89', 'title': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£16.77', 'title': 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£20.59', 'title': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£37.13', 'title': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£56.06', 'title': 'The Electric Pencil: Drawings from Inside State Hospital No. 3'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£58.11', 'title': 'The Death of Humanity: and the Case for Life'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£49.05', 'title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£40.76', 'title': 'The Art Forger'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£19.73', 'title': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£32.24', 'title': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution"}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£41.83', 'title': 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£39.58', 'title': 'Soul Reader'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£39.25', 'title': 'Security'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£25.02', 'title': 'Saga, Volume 6 (Saga (Collected Editions) #6)'}
# 2022-09-10 16:25:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-5.html> (referer: http://books.toscrape.com/catalogue/page-4.html)
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£51.04', 'title': 'Saga, Volume 5 (Saga (Collected Editions) #5)'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£19.83', 'title': 'Reskilling America: Learning to Labor in the Twenty-First Century'}
# 2022-09-10 16:25:17 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'price': '£50.40', 'title': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£13.61', 'title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£13.34', 'title': 'Princess Between Worlds (Wide-Awake Princess #5)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£18.97', 'title': 'Pop Gun War, Volume 1: Gift'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£36.28', 'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£10.16', 'title': 'Patience'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£15.44', 'title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£48.41', 'title': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£46.35', 'title': 'Online Marketing for Busy Authors: A Step-By-Step Guide'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£14.07', 'title': 'On a Midnight Clear'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£14.86', 'title': 'Obsidian (Lux #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£33.37', 'title': 'My Paris Kitchen: Recipes and Stories'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£56.40', 'title': 'Masks and Shadows'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£14.02', 'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£46.91', 'title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£45.61', 'title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£19.92', 'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£40.11', 'title': 'Layered: Baking, Building, and Styling Spectacular Cakes'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£53.90', 'title': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£35.67', 'title': 'Join'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'price': '£22.00', 'title': 'In the Country We Love: My Family Divided'}
# 2022-09-10 16:25:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-6.html> (referer: http://books.toscrape.com/catalogue/page-5.html)
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£57.36', 'title': 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£29.17', 'title': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£54.63', 'title': 'I am a Hero Omnibus Volume 1'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£46.03', 'title': 'How to Be Miserable: 40 Strategies You Already Use'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£33.97', 'title': 'Her Backup Boyfriend (The Sorensen Family #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£22.11', 'title': 'Giant Days, Vol. 2 (Giant Days #5-8)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£29.69', 'title': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£15.97', 'title': 'First and First (Five Boroughs #3)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£21.96', 'title': 'Fifty Shades Darker (Fifty Shades #2)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£54.35', 'title': 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£37.97', 'title': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master"}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£51.99', 'title': 'Danganronpa Volume 1'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£43.29', 'title': 'Crown of Midnight (Throne of Glass #2)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£36.72', 'title': 'Codename Baboushka, Volume 1: The Conclave of Death'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£17.08', 'title': 'Camp Midnight'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£29.14', 'title': 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£28.81', 'title': 'Burning'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£49.46', 'title': 'Bossypants'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£37.92', 'title': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'price': '£28.09', 'title': 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)'}
# 2022-09-10 16:25:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-7.html> (referer: http://books.toscrape.com/catalogue/page-6.html)
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£30.81', 'title': 'Algorithms to Live By: The Computer Science of Human Decisions'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£42.95', 'title': 'A World of Flavor: Your Gluten Free Passport'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£56.76', 'title': 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£16.64', 'title': 'A Murder in Time'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£55.53', 'title': 'A Flight of Arrows (The Pathfinders #2)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£28.13', 'title': 'A Fierce and Subtle Poison'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£52.37', 'title': 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£54.00', 'title': '(Un)Qualified: How God Uses Broken People to Do Big Things'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£21.87', 'title': 'You Are What You Love: The Spiritual Power of Habit'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£43.30', 'title': "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)"}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£21.04', 'title': 'Tuesday Nights in 1980'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£41.60', 'title': 'Tracing Numbers on a Train'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£35.07', 'title': 'Throne of Glass (Throne of Glass #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£59.64', 'title': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£52.72', 'title': 'Thirteen Reasons Why'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£58.08', 'title': 'The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£24.12', 'title': 'The Wedding Dress'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£42.15', 'title': 'The Vacationers'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£12.61', 'title': 'The Third Wave: An Entrepreneur’s Vision of the Future'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'price': '£17.44', 'title': 'The Stranger'}
# 2022-09-10 16:25:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-8.html> (referer: http://books.toscrape.com/catalogue/page-7.html)
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£33.14', 'title': 'The Shadow Hero (The Shadow Hero)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£27.37', 'title': 'The Secret (The Secret #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£51.36', 'title': 'The Regional Office Is Under Attack!'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£36.00', 'title': 'The Psychopath Test: A Journey Through the Madness Industry'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£10.65', 'title': 'The Project'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£43.54', 'title': 'The Power of Now: A Guide to Spiritual Enlightenment'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£38.21', 'title': "The Omnivore's Dilemma: A Natural History of Four Meals"}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£37.34', 'title': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£44.10', 'title': 'The Murder of Roger Ackroyd (Hercule Poirot #4)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£43.29', 'title': 'The Mistake (Off-Campus #2)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£55.85', 'title': "The Matchmaker's Playbook (Wingmen Inc. #1)"}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£37.60', 'title': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£10.97', 'title': 'The Long Shadow of Small Ghosts: Murder and Memory in an American City'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£41.82', 'title': 'The Kite Runner'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£36.95', 'title': 'The House by the Lake'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£44.28', 'title': 'The Glittering Court (The Glittering Court #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£55.02', 'title': 'The Girl on the Train'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£17.24', 'title': 'The Genius of Birds'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£23.15', 'title': 'The Emerald Mystery'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'price': '£41.25', 'title': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First'}
# 2022-09-10 16:25:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-9.html> (referer: http://books.toscrape.com/catalogue/page-8.html)
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£32.00', 'title': "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs."}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£38.49', 'title': "The Artist's Way: A Spiritual Path to Higher Creativity"}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£33.34', 'title': 'The Art of War'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£10.93', 'title': 'The Argonauts'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£27.55', 'title': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£55.99', 'title': 'Suddenly in Love (Lake Haven #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£16.24', 'title': 'Something More Than This'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£26.12', 'title': 'Soft Apocalypse'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£12.23', 'title': "So You've Been Publicly Shamed"}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£23.99', 'title': 'Shoe Dog: A Memoir by the Creator of NIKE'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£29.06', 'title': 'Shobu Samurai, Project Aryoku (#3)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£20.27', 'title': 'Secrets and Lace (Fatal Hearts #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£43.55', 'title': 'Scarlett Epstein Hates It Here'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£36.94', 'title': 'Romero and Juliet: A Tragic Tale of Love and Zombies'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£20.47', 'title': 'Redeeming Love'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£41.06', 'title': 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£14.19', 'title': 'Poems That Make Grown Women Cry'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£38.28', 'title': 'Nightingale, Sing'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£41.05', 'title': 'Night Sky with Exit Wounds'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'price': '£30.25', 'title': 'Mrs. Houdini'}
# 2022-09-10 16:25:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-10.html> (referer: http://books.toscrape.com/catalogue/page-9.html)
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£28.26', 'title': 'Modern Romance'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£10.76', 'title': 'Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£16.85', 'title': 'Louisa: The Extraordinary Life of Mrs. Adams'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£13.47', 'title': 'Little Red'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£48.56', 'title': 'Library of Souls (Miss Peregrine’s Peculiar Children #3)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£19.15', 'title': 'Large Print Heart of the Pride'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£57.36', 'title': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£42.98', 'title': 'Hollow City (Miss Peregrine’s Peculiar Children #2)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£22.16', 'title': 'Grumbles'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£49.43', 'title': 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£29.99', 'title': 'Frostbite (Vampire Academy #2)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£21.36', 'title': 'Follow You Home'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£29.00', 'title': 'First Steps for New Christians (Print Edition)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£53.53', 'title': 'Finders Keepers (Bill Hodges Trilogy #2)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£41.62', 'title': 'Fables, Vol. 1: Legends in Exile (Fables #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£54.59', 'title': 'Eureka Trivia 6.0'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£34.95', 'title': 'Drive: The Surprising Truth About What Motivates Us'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£37.72', 'title': 'Done Rubbed Out (Reightman & Bailey #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£35.61', 'title': 'Doing It Over (Most Likely To #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'price': '£42.16', 'title': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals'}
# 2022-09-10 16:25:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-11.html> (referer: http://books.toscrape.com/catalogue/page-10.html)
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£19.19', 'title': 'Dark Notes'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£19.43', 'title': 'Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£49.46', 'title': 'Close to You'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£37.80', 'title': 'Chasing Heaven: What Dying Taught Me About Living'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£30.80', 'title': 'Big Magic: Creative Living Beyond Fear'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£27.43', 'title': 'Becoming Wise: An Inquiry into the Mystery and Art of Living'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£11.11', 'title': 'Beauty Restored (Riley Family Legacy Novellas #3)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£36.50', 'title': 'Batman: The Long Halloween (Batman)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£15.38', 'title': 'Batman: The Dark Knight Returns (Batman)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£15.48', 'title': "Ayumi's Violin"}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£46.82', 'title': 'Anonymous'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£18.46', 'title': 'Amy Meets the Saints and Sages'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£36.58', 'title': 'Amid the Chaos'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£50.54', 'title': 'Amatus'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£12.51', 'title': 'Agnostic: A Spirited Manifesto'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£24.70', 'title': 'Zealot: The Life and Times of Jesus of Nazareth'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£43.61', 'title': 'You (You #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£37.34', 'title': 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£14.36', 'title': 'Wild Swans'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'price': '£52.65', 'title': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond'}
# 2022-09-10 16:25:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-12.html> (referer: http://books.toscrape.com/catalogue/page-11.html)
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-12.html>
# {'price': '£38.20', 'title': 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-12.html>
# {'price': '£19.60', 'title': "What's It Like in Space?: Stories from Astronauts Who've Been There"}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-12.html>
# {'price': '£53.90', 'title': 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-12.html>
# {'price': '£12.96', 'title': "Walt Disney's Alice in Wonderland"}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-12.html>
# {'price': '£37.10', 'title': 'V for Vendetta (V for Vendetta Complete)'}
# 2022-09-10 16:25:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-12.html>
# {'price': '£46.31', 'title': 'Until Friday Night (The Field Party #1)'}
# ...
# {'price': '£54.12', 'title': 'The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£33.78', 'title': 'The Republic'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£29.64', 'title': 'The Odyssey'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£57.70', 'title': "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)"}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£36.34', 'title': 'The Nicomachean Ethics'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£50.59', 'title': 'The Name of the Wind (The Kingkiller Chronicle #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£29.38', 'title': 'The Mirror & the Maze (The Wrath and the Dawn #1.5)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£45.42', 'title': 'The Little Prince'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£54.43', 'title': 'The Light of the Fireflies'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£36.26', 'title': 'The Last Girl (The Dominion Trilogy #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£16.16', 'title': 'The Iliad'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£36.29', 'title': 'The Hook Up (Game On #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£27.89', 'title': 'The Haters'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£12.29', 'title': 'The Girl You Lost'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£15.85', 'title': 'The Girl In The Ice (DCI Erika Foster #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£14.40', 'title': 'The End of the Jesus Era (An Investigation #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£19.18', 'title': 'The Edge of Reason (Bridget Jones #2)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£10.64', 'title': 'The Complete Maus (Maus #1-2)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'price': '£14.76', 'title': 'The Communist Manifesto'}
# 2022-09-10 16:25:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-48.html> (referer: http://books.toscrape.com/catalogue/page-47.html)
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£57.49', 'title': 'The Bhagavad Gita'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£30.66', 'title': 'The Bette Davis Club'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£40.83', 'title': 'The Art of Not Breathing'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£18.88', 'title': 'Taking Shots (Assassins #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£25.83', 'title': 'Starlark'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£42.12', 'title': 'Skip Beat!, Vol. 01 (Skip Beat! #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£13.33', 'title': 'Sister Sable (The Mad Queen #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£42.40', 'title': 'Shatter Me (Shatter Me #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£58.35', 'title': 'Shameless'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£21.72', 'title': 'Shadow Rites (Jane Yellowrock #10)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£44.91', 'title': 'Settling the Score (The Summer Games #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£37.46', 'title': 'Sense and Sensibility'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£28.48', 'title': 'Saga, Volume 1 (Saga (Collected Editions) #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£28.34', 'title': 'Rhythm, Chord & Malykhin'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£46.96', 'title': 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£24.96', 'title': 'Paradise Lost (Paradise #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£21.71', 'title': 'Paper Girls, Vol. 1 (Paper Girls #1-5)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£29.87', 'title': 'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£28.99', 'title': 'Origins (Alphas 0.5)'}
# 2022-09-10 16:25:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'price': '£52.94', 'title': 'One Second (Seven #7)'}
# 2022-09-10 16:25:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-49.html> (referer: http://books.toscrape.com/catalogue/page-48.html)
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£32.36', 'title': 'On the Road (Duluoz Legend)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£55.66', 'title': "Old Records Never Die: One Man's Quest for His Vinyl and His Past"}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£39.45', 'title': 'Off Sides (Off #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£47.11', 'title': 'Of Mice and Men'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£58.75', 'title': 'Myriad (Prentor #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£38.92', 'title': 'My Perfect Mistake (Over the Top #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£39.39', 'title': 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£25.89', 'title': 'Meditations'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£28.34', 'title': 'Matilda'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£27.70', 'title': 'Lost Among the Living'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£24.89', 'title': 'Lord of the Flies'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£58.99', 'title': 'Listen to Me (Fusion #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£57.20', 'title': 'Kitchens of the Great Midwest'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£38.43', 'title': 'Jane Eyre'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£34.74', 'title': 'Imperfect Harmony'}
# 2022-09-10 16:25:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-50.html> (referer: http://books.toscrape.com/catalogue/page-49.html)
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£40.44', 'title': 'Icing (Aces Hockey #2)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£45.24', 'title': 'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£34.96', 'title': "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)"}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£56.76', 'title': 'Giant Days, Vol. 1 (Giant Days #1-4)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'price': '£40.28', 'title': 'Fruits Basket, Vol. 1 (Fruits Basket #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£38.00', 'title': 'Frankenstein'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£28.80', 'title': 'Forever Rockers (The Rocker #12)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£39.24', 'title': 'Fighting Fate (Fighting #6)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£32.93', 'title': 'Emma'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£51.32', 'title': 'Eat, Pray, Love'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£47.09', 'title': 'Deep Under (Walker Security #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£28.42', 'title': "Choosing Our Religion: The Spiritual Lives of America's Nones"}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£22.85', 'title': 'Charlie and the Chocolate Factory (Charlie Bucket #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£41.24', 'title': "Charity's Cross (Charles Towne Belles #4)"}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£39.07', 'title': 'Bright Lines'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£29.82', 'title': "Bridget Jones's Diary (Bridget Jones #1)"}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£37.26', 'title': 'Bounty (Colorado Mountain #7)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£20.30', 'title': 'Blood Defense (Samantha Brinkman #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£34.65', 'title': 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£43.38', 'title': 'Beyond Good and Evil'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£55.53', 'title': "Alice in Wonderland (Alice's Adventures in Wonderland #1)"}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£57.06', 'title': 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)'}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£16.97', 'title': "A Spy's Devotion (The Regency Spies of London #1)"}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£53.98', 'title': "1st to Die (Women's Murder Club #1)"}
# 2022-09-10 16:25:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'price': '£26.08', 'title': '1,000 Places to See Before You Die'}
# 2022-09-10 16:25:24 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-09-10 16:25:24 [scrapy.extensions.feedexport] INFO: Stored csv feed (1000 items) in: books.csv
# 2022-09-10 16:25:24 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 14831,
#  'downloader/request_count': 50,
#  'downloader/request_method_count/GET': 50,
#  'downloader/response_bytes': 2552711,
#  'downloader/response_count': 50,
#  'downloader/response_status_count/200': 50,
#  'dupefilter/filtered': 931,
#  'elapsed_time_seconds': 6.895327,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 9, 10, 16, 25, 24, 208801),
#  'item_scraped_count': 1000,
#  'log_count/DEBUG': 1052,
#  'log_count/INFO': 11,
#  'memusage/max': 102490112,
#  'memusage/startup': 102490112,
#  'request_depth_max': 49,
#  'response_received_count': 50,
#  'scheduler/dequeued': 50,
#  'scheduler/dequeued/memory': 50,
#  'scheduler/enqueued': 50,
#  'scheduler/enqueued/memory': 50,
#  'start_time': datetime.datetime(2022, 9, 10, 16, 25, 17, 313474)}
# 2022-09-10 16:25:24 [scrapy.core.engine] INFO: Spider closed (finished)
